# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
ac = pd.read_csv("C:/Files/VS/Codes/Intro to ai and ml/activity.csv")

# %%
ac.head()
# Out:
#    user activity      timestamp  x-axis  y-axis  z-axis
# 0     1  Walking  4991922345000    0.69   10.80   -2.03
# 1     1  Walking  4991972333000    6.85    7.44   -0.50
# 2     1  Walking  4992022351000    0.93    5.63   -0.50
# 3     1  Walking  4992072339000   -2.11    5.01   -0.69
# 4     1  Walking  4992122358000   -4.59    4.29   -1.95

# %%
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1073623 entries, 0 to 1073622
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user       1073623 non-null  int64
#  1   activity   1073623 non-null  object
#  2   timestamp  1073623 non-null  int64
#  3   x-axis     1073623 non-null  float64
#  4   y-axis     1073623 non-null  float64
#  5   z-axis     1073623 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 49.1+ MB

# %%
ac.shape
# Out:
# (1073623, 6)

# %%
gp = ac.plot(kind="scatter", x="x-axis",   y="activity")
gp.set_title("Activity vs X-axis")
plt.show()

# %%
gp = ac.plot(kind="scatter", x="y-axis",   y="activity")
gp.set_title("Activity vs Y-axis")
plt.show()

# %%
gp = ac.plot(kind="scatter", x="z-axis",   y="activity")
gp.set_title("Activity vs Z-axis")
plt.show()

# %%
x = ac.drop(columns = ["user", "activity", "timestamp"])
y = ac["activity"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
print(x_train.head())
print(y_train.head())
print(x_test.head())
print(y_test.head())
# Out:
#         x-axis  y-axis    z-axis
# 143040   -1.42    6.51 -0.721878
# 176596    1.57    9.81 -1.920000
# 674419   -2.91   15.94  1.540000
# 460368    1.12    9.92  0.190000
# 342248    5.41    5.01  6.890000
# 143040     Walking
# 176596     Walking
# 674419     Jogging
# 460368    Standing
# 342248     Sitting
# Name: activity, dtype: object
#         x-axis  y-axis  z-axis
# 621588    2.49   12.95    9.08
# 7945      6.89  -11.54   -5.37
# 920415    7.70   -1.95    4.52
# 407261   -2.26    8.20   -2.45
# 230818    2.41    4.79   -1.23
# 621588    Walking
# 7945      Jogging
# 920415    Sitting
# 407261    Walking
# 230818    Walking
# Name: activity, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test, pred)*100

# %%
print(f"Accuracy : {acc}%")
# Out:
# Accuracy : 47.66748166259169%
